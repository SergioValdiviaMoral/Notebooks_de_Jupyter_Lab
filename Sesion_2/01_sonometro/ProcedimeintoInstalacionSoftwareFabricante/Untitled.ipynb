# %% [markdown]
# ![image.png](attachment:848443af-01fa-447d-9f01-f3e8d97ab33b.png)
#
#
# ![image.png](attachment:ccf8ea26-a9f9-4212-871f-d35931d54685.png)
# Debaria de ir en c PREGRAMAS
#
#
# aCEPTAMOS CONDICIONES
# ![image.png](attachment:24643933-b292-4bde-9688-40f3455d9786.png)
#
#
# Continuamos
#
# ![image.png](attachment:6f87360d-e86e-47eb-9e8a-6a3c669eb46f.png)
#
# Se instala
#
# ![image.png](attachment:8f5691d0-6a13-473e-8f8f-9810b9efa05a.png)

# %% [markdown]
# Nos debe de dar este fallo
#
#
# ![image.png](attachment:22917ec9-4982-41ce-9444-0376a45f25f6.png)
#
#
# Boton derecho en el dispositivo y seleccionamos
# ![image.png](attachment:49d94c48-1fbc-406a-8c5e-081556ff1ef1.png)
