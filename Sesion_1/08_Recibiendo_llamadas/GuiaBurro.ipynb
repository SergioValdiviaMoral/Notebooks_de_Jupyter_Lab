# %% [markdown]
# # Procedimiento de uso de MicroSIP
#
# ## Fecha
# ### Sergio Valdivia Moral (svm@ugr.es)

# %% [markdown]
# Para capturar la imagen de forma rapida pulso: Mayus + Windows + S
#
# Y seleccionamos la porción de pantalla que queremos
#
# ![image.png](attachment:3ebcbb47-1882-4675-b44d-64f1ded70d70.png)
