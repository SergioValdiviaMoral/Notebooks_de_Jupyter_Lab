# %% [markdown]
# # Manual para administración de Equipos
#
#
# Vamos a administrador de Equipo/Mi PC y pulsamos en admisnitrar (En windows 11 es Equipo en busqueda)
#
# ![Captura de pantalla (1).png](attachment:4d1ef005-13ee-4065-9489-fb23951b1387.png)
#
#
#
#
# A continuación abrimos como administrador
#
# ![image.png](attachment:3fc60370-29c9-4b3e-9f0d-98941d4dd497.png)
#
#
# Vamos a Administrador de Equipo
#
# ![image.png](attachment:3ed0304a-049b-463f-88cc-b077d6a1f392.png)
#
#
# Pulsamos botón derecho en el disco  y seleccionamos particion / Reducir Volumen
#
# ![image.png](attachment:579fbecb-4b3a-4174-ab58-055fad3565b5.png)
#
# Seleccionamos la cantidad que queremos reducir, hay que dejar sufciente espacio paa poder instalar mas programas en el futuro
#
# ![image.png](attachment:05283e4c-39b8-46df-8246-5b0c46d12e1f.png)
#
#
# En el espacio en negro pulsamos en crear nuevo disco
